# %%
import pandas as pd
import numpy as np

# %%
api_response = 'https://api.github.com/repos/pandas-dev/pandas/issues'
df_api_resonse = pd.read_json(api_response)

# %%
df_api_resonse.head()
# Out:
#                                                  url  \
# 0  https://api.github.com/repos/pandas-dev/pandas...
# 1  https://api.github.com/repos/pandas-dev/pandas...
# 2  https://api.github.com/repos/pandas-dev/pandas...
# 3  https://api.github.com/repos/pandas-dev/pandas...
# 4  https://api.github.com/repos/pandas-dev/pandas...
#
#                                    repository_url  \
# 0  https://api.github.com/repos/pandas-dev/pandas
# 1  https://api.github.com/repos/pandas-dev/pandas
# 2  https://api.github.com/repos/pandas-dev/pandas
# 3  https://api.github.com/repos/pandas-dev/pandas
# 4  https://api.github.com/repos/pandas-dev/pandas
#
#                                           labels_url  \
# 0  https://api.github.com/repos/pandas-dev/pandas...
# 1  https://api.github.com/repos/pandas-dev/pandas...
# 2  https://api.github.com/repos/pandas-dev/pandas...
# 3  https://api.github.com/repos/pandas-dev/pandas...
# 4  https://api.github.com/repos/pandas-dev/pandas...
#
# ...

# %%
import requests
data = requests.get(api_response)

# %%
data
# Out:
# <Response [200]>

# %%
resp = data.json()

# %%
print(type(resp))
# Out:
# <class 'list'>

# %%
resp
# Out:
# [{'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/60100',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/60100/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/60100/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/60100/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/60100',
#   'id': 2611653602,
#   'node_id': 'PR_kwDOAA0YD85_xwaF',
#   'number': 60100,
#   'title': 'BUG: `read_csv` with chained fsspec TAR file and `compression="infer"` fails with `tarfile.ReadError`',
#   'user': {'login': 'KevsterAmp',
#    'id': 109636487,
#    'node_id': 'U_kgDOBojrhw',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/109636487?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/KevsterAmp',
#    'html_url': 'https://github.com/KevsterAmp',
# ...

# %%
df = pd.DataFrame(resp)

# %%
df
# Out:
#                                                   url  \
# 0   https://api.github.com/repos/pandas-dev/pandas...
# 1   https://api.github.com/repos/pandas-dev/pandas...
# 2   https://api.github.com/repos/pandas-dev/pandas...
# 3   https://api.github.com/repos/pandas-dev/pandas...
# 4   https://api.github.com/repos/pandas-dev/pandas...
# 5   https://api.github.com/repos/pandas-dev/pandas...
# 6   https://api.github.com/repos/pandas-dev/pandas...
# 7   https://api.github.com/repos/pandas-dev/pandas...
# 8   https://api.github.com/repos/pandas-dev/pandas...
# 9   https://api.github.com/repos/pandas-dev/pandas...
# 10  https://api.github.com/repos/pandas-dev/pandas...
# 11  https://api.github.com/repos/pandas-dev/pandas...
# 12  https://api.github.com/repos/pandas-dev/pandas...
# 13  https://api.github.com/repos/pandas-dev/pandas...
# 14  https://api.github.com/repos/pandas-dev/pandas...
# 15  https://api.github.com/repos/pandas-dev/pandas...
# ...

# %%
df.columns
# Out:
# Index(['url', 'repository_url', 'labels_url', 'comments_url', 'events_url',
#        'html_url', 'id', 'node_id', 'number', 'title', 'user', 'labels',
#        'state', 'locked', 'assignee', 'assignees', 'milestone', 'comments',
#        'created_at', 'updated_at', 'closed_at', 'author_association',
#        'active_lock_reason', 'draft', 'pull_request', 'body', 'closed_by',
#        'reactions', 'timeline_url', 'performed_via_github_app',
#        'state_reason'],
#       dtype='object')

# %%
df['node_id']
# Out:
# 0     PR_kwDOAA0YD85_xwaF
# 1      I_kwDOAA0YD86bqkgb
# 2      I_kwDOAA0YD86bpaaY
# 3     PR_kwDOAA0YD85_t_Mu
# 4      I_kwDOAA0YD86bkOz6
# 5      I_kwDOAA0YD86bjXen
# 6      I_kwDOAA0YD86bjFKe
# 7     PR_kwDOAA0YD85_ptgS
# 8      I_kwDOAA0YD86bf37c
# 9      I_kwDOAA0YD86bfLxg
# 10     I_kwDOAA0YD86beHFr
# 11     I_kwDOAA0YD86bYgEQ
# 12     I_kwDOAA0YD86bXHI1
# 13     I_kwDOAA0YD86bUxOh
# 14    PR_kwDOAA0YD85_ZjuP
# 15     I_kwDOAA0YD86bL_kQ
# 16     I_kwDOAA0YD86bHXik
# 17     I_kwDOAA0YD86bDDGK
# 18    PR_kwDOAA0YD85_PXa9
# 19    PR_kwDOAA0YD85_O2mE
# 20     I_kwDOAA0YD86a_8pr
# 21     I_kwDOAA0YD86a4B-k
# 22    PR_kwDOAA0YD85_I9AC
# 23     I_kwDOAA0YD86a2qKF
# 24    PR_kwDOAA0YD85_H9qe
# 25     I_kwDOAA0YD86a0vAY
# 26    PR_kwDOAA0YD85_E4_g
# 27     I_kwDOAA0YD86awA57
# 28     I_kwDOAA0YD86atBwj
# 29     I_kwDOAA0YD86asQRk
# Name: node_id, dtype: object

# %%
df.to_csv('info_csv.csv')

# %% [markdown]
# # working with dataset

# %%
df = pd.read_csv('https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv')

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df.shape
# Out:
# (891, 12)

# %%
df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
# seprate integer , float and object datatypes
int_columns = [i for i in df.columns if df[i].dtypes=='int64']
float_columns = [i for i in df.columns if df[i].dtypes=='float64']
string_columns  = [i for i in df.columns if df[i].dtypes=='object']

# %%
df[string_columns]
# Out:
#                                                   Name     Sex  \
# 0                              Braund, Mr. Owen Harris    male
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                               Heikkinen, Miss. Laina  female
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                             Allen, Mr. William Henry    male
# ..                                                 ...     ...
# 886                              Montvila, Rev. Juozas    male
# 887                       Graham, Miss. Margaret Edith  female
# 888           Johnston, Miss. Catherine Helen "Carrie"  female
# 889                              Behr, Mr. Karl Howell    male
# 890                                Dooley, Mr. Patrick    male
#
#                Ticket Cabin Embarked
# 0           A/5 21171   NaN        S
# 1            PC 17599   C85        C
# 2    STON/O2. 3101282   NaN        S
# 3              113803  C123        S
# ...

# %%
obj = df[df.dtypes[df.dtypes=='object'].index]

# %%
int64 = df[df.columns[df.dtypes!='object']]

# %%
int64
# Out:
#      PassengerId  Survived  Pclass   Age  SibSp  Parch     Fare
# 0              1         0       3  22.0      1      0   7.2500
# 1              2         1       1  38.0      1      0  71.2833
# 2              3         1       3  26.0      0      0   7.9250
# 3              4         1       1  35.0      1      0  53.1000
# 4              5         0       3  35.0      0      0   8.0500
# ..           ...       ...     ...   ...    ...    ...      ...
# 886          887         0       2  27.0      0      0  13.0000
# 887          888         1       1  19.0      0      0  30.0000
# 888          889         0       3   NaN      1      2  23.4500
# 889          890         1       1  26.0      0      0  30.0000
# 890          891         0       3  32.0      0      0   7.7500
#
# [891 rows x 7 columns]

# %%
obj.describe()
# Out:
#                            Name   Sex  Ticket    Cabin Embarked
# count                       891   891     891      204      889
# unique                      891     2     681      147        3
# top     Braund, Mr. Owen Harris  male  347082  B96 B98        S
# freq                          1   577       7        4      644

# %%
df.describe(include='object') # show desptive stats for object data type
# Out:
#                            Name   Sex  Ticket    Cabin Embarked
# count                       891   891     891      204      889
# unique                      891     2     681      147        3
# top     Braund, Mr. Owen Harris  male  347082  B96 B98        S
# freq                          1   577       7        4      644

# %%
df.axes
# Out:
# [RangeIndex(start=0, stop=891, step=1),
#  Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#         'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#        dtype='object')]

# %%
df.sort_values(by='Fare')
# Out:
#      PassengerId  Survived  Pclass                                Name  \
# 271          272         1       3        Tornquist, Mr. William Henry
# 597          598         0       3                 Johnson, Mr. Alfred
# 302          303         0       3     Johnson, Mr. William Cahoone Jr
# 633          634         0       1       Parr, Mr. William Henry Marsh
# 277          278         0       2         Parkes, Mr. Francis "Frank"
# ..           ...       ...     ...                                 ...
# 438          439         0       1                   Fortune, Mr. Mark
# 341          342         1       1      Fortune, Miss. Alice Elizabeth
# 737          738         1       1              Lesurer, Mr. Gustave J
# 258          259         1       1                    Ward, Miss. Anna
# 679          680         1       1  Cardeza, Mr. Thomas Drake Martinez
#
#         Sex   Age  SibSp  Parch    Ticket      Fare        Cabin Embarked
# ...

# %%
df.rename(columns={'PassengerId':'passengerId'})
# Out:
#      passengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.describe(include='all')
# Out:
#         PassengerId    Survived      Pclass                     Name   Sex  \
# count    891.000000  891.000000  891.000000                      891   891
# unique          NaN         NaN         NaN                      891     2
# top             NaN         NaN         NaN  Braund, Mr. Owen Harris  male
# freq            NaN         NaN         NaN                        1   577
# mean     446.000000    0.383838    2.308642                      NaN   NaN
# std      257.353842    0.486592    0.836071                      NaN   NaN
# min        1.000000    0.000000    1.000000                      NaN   NaN
# 25%      223.500000    0.000000    2.000000                      NaN   NaN
# 50%      446.000000    0.000000    3.000000                      NaN   NaN
# 75%      668.500000    1.000000    3.000000                      NaN   NaN
# max      891.000000    1.000000    3.000000                      NaN   NaN
#
# ...

# %%
df[df.dtypes[df.dtypes=='object'].index]
df[df.columns[df.dtypes=='int64']]
df[[i for i in df.columns if df[i].dtypes=='float64']]
# Out:
#       Age     Fare
# 0    22.0   7.2500
# 1    38.0  71.2833
# 2    26.0   7.9250
# 3    35.0  53.1000
# 4    35.0   8.0500
# ..    ...      ...
# 886  27.0  13.0000
# 887  19.0  30.0000
# 888   NaN  23.4500
# 889  26.0  30.0000
# 890  32.0   7.7500
#
# [891 rows x 2 columns]

# %% [markdown]
# slicing of rowws

# %%
df[10:100]
# Out:
#     PassengerId  Survived  Pclass                                  Name  \
# 10           11         1       3       Sandstrom, Miss. Marguerite Rut
# 11           12         1       1              Bonnell, Miss. Elizabeth
# 12           13         0       3        Saundercock, Mr. William Henry
# 13           14         0       3           Andersson, Mr. Anders Johan
# 14           15         0       3  Vestrom, Miss. Hulda Amanda Adolfina
# ..          ...       ...     ...                                   ...
# 95           96         0       3           Shorney, Mr. Charles Joseph
# 96           97         0       1             Goldschmidt, Mr. George B
# 97           98         1       1       Greenfield, Mr. William Bertram
# 98           99         1       2  Doling, Mrs. John T (Ada Julia Bone)
# 99          100         0       2                     Kantor, Mr. Sinai
#
#        Sex   Age  SibSp  Parch     Ticket     Fare    Cabin Embarked
# ...

# %%
df[1:10:1]
# Out:
#    PassengerId  Survived  Pclass  \
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# 6                            McCarthy, Mr. Timothy J    male  54.0      0
# 7                     Palsson, Master. Gosta Leonard    male   2.0      3
# ...

# %%
# if we want to add new column in data frame 
df['new col']="vicky"

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked', 'new col'],
#       dtype='object')

# %%
# if we want to make new column based on 2 diffrent columns  of data frame
# here we are going to create new column as family couunt as we have Parch Parch
df['family count'] = df['Parch'] + df['SibSp']

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.drop(columns='new col',inplace=True)

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked', 'family count'],
#       dtype='object')

# %%
pd.Categorical(df['Pclass']) # here we will get lenght and unique value  and number of unique value
# Out:
# [3, 1, 3, 1, 3, ..., 2, 1, 3, 1, 3]
# Length: 891
# Categories (3, int64): [1, 2, 3]

# %%
obj
# Out:
#                                                   Name     Sex  \
# 0                              Braund, Mr. Owen Harris    male
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                               Heikkinen, Miss. Laina  female
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                             Allen, Mr. William Henry    male
# ..                                                 ...     ...
# 886                              Montvila, Rev. Juozas    male
# 887                       Graham, Miss. Margaret Edith  female
# 888           Johnston, Miss. Catherine Helen "Carrie"  female
# 889                              Behr, Mr. Karl Howell    male
# 890                                Dooley, Mr. Patrick    male
#
#                Ticket Cabin Embarked
# 0           A/5 21171   NaN        S
# 1            PC 17599   C85        C
# 2    STON/O2. 3101282   NaN        S
# 3              113803  C123        S
# ...

# %%
pd.Categorical(df['Embarked'])
# Out:
# ['S', 'C', 'S', 'S', 'S', ..., 'S', 'S', 'S', 'C', 'Q']
# Length: 891
# Categories (3, object): ['C', 'Q', 'S']

# %%
# if we want to find unique value

print(df['Cabin'].unique())
# Out:
# [nan 'C85' 'C123' 'E46' 'G6' 'C103' 'D56' 'A6' 'C23 C25 C27' 'B78' 'D33'
#  'B30' 'C52' 'B28' 'C83' 'F33' 'F G73' 'E31' 'A5' 'D10 D12' 'D26' 'C110'
#  'B58 B60' 'E101' 'F E69' 'D47' 'B86' 'F2' 'C2' 'E33' 'B19' 'A7' 'C49'
#  'F4' 'A32' 'B4' 'B80' 'A31' 'D36' 'D15' 'C93' 'C78' 'D35' 'C87' 'B77'
#  'E67' 'B94' 'C125' 'C99' 'C118' 'D7' 'A19' 'B49' 'D' 'C22 C26' 'C106'
#  'C65' 'E36' 'C54' 'B57 B59 B63 B66' 'C7' 'E34' 'C32' 'B18' 'C124' 'C91'
#  'E40' 'T' 'C128' 'D37' 'B35' 'E50' 'C82' 'B96 B98' 'E10' 'E44' 'A34'
#  'C104' 'C111' 'C92' 'E38' 'D21' 'E12' 'E63' 'A14' 'B37' 'C30' 'D20' 'B79'
#  'E25' 'D46' 'B73' 'C95' 'B38' 'B39' 'B22' 'C86' 'C70' 'A16' 'C101' 'C68'
#  'A10' 'E68' 'B41' 'A20' 'D19' 'D50' 'D9' 'A23' 'B50' 'A26' 'D48' 'E58'
#  'C126' 'B71' 'B51 B53 B55' 'D49' 'B5' 'B20' 'F G63' 'C62 C64' 'E24' 'C90'
#  'C45' 'E8' 'B101' 'D45' 'C46' 'D30' 'E121' 'D11' 'E77' 'F38' 'B3' 'D6'
#  'B82 B84' 'D17' 'A36' 'B102' 'B69' 'E49' 'C47' 'D28' 'E17' 'A24' 'C50'
#  'B42' 'C148']

# %%
# if we want number of unique value then 
df['Cabin'].nunique()
# Out:
# 147

# %%
df['Cabin'].value_counts()
# Out:
# Cabin
# B96 B98        4
# G6             4
# C23 C25 C27    4
# C22 C26        3
# F33            3
#               ..
# E34            1
# C7             1
# C54            1
# E36            1
# C148           1
# Name: count, Length: 147, dtype: int64

# %%
df['Age'].value_counts()
# Out:
# Age
# 24.00    30
# 22.00    27
# 18.00    26
# 19.00    25
# 28.00    25
#          ..
# 36.50     1
# 55.50     1
# 0.92      1
# 23.50     1
# 74.00     1
# Name: count, Length: 88, dtype: int64

# %%
df['Age'].unique()
# Out:
# array([22.  , 38.  , 26.  , 35.  ,   nan, 54.  ,  2.  , 27.  , 14.  ,
#         4.  , 58.  , 20.  , 39.  , 55.  , 31.  , 34.  , 15.  , 28.  ,
#         8.  , 19.  , 40.  , 66.  , 42.  , 21.  , 18.  ,  3.  ,  7.  ,
#        49.  , 29.  , 65.  , 28.5 ,  5.  , 11.  , 45.  , 17.  , 32.  ,
#        16.  , 25.  ,  0.83, 30.  , 33.  , 23.  , 24.  , 46.  , 59.  ,
#        71.  , 37.  , 47.  , 14.5 , 70.5 , 32.5 , 12.  ,  9.  , 36.5 ,
#        51.  , 55.5 , 40.5 , 44.  ,  1.  , 61.  , 56.  , 50.  , 36.  ,
#        45.5 , 20.5 , 62.  , 41.  , 52.  , 63.  , 23.5 ,  0.92, 43.  ,
#        60.  , 10.  , 64.  , 13.  , 48.  ,  0.75, 53.  , 57.  , 80.  ,
#        70.  , 24.5 ,  6.  ,  0.67, 30.5 ,  0.42, 34.5 , 74.  ])

# %%
l1 = np.where(df['Age']<5)

# %%
df[df['Age']<5] # child passenger
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 7              8         0       3            Palsson, Master. Gosta Leonard
# 10            11         1       3           Sandstrom, Miss. Marguerite Rut
# 16            17         0       3                      Rice, Master. Eugene
# 43            44         1       2  Laroche, Miss. Simonne Marie Anne Andree
# 63            64         0       3                     Skoog, Master. Harald
# 78            79         1       2             Caldwell, Master. Alden Gates
# 119          120         0       3         Andersson, Miss. Ellis Anna Maria
# 164          165         0       3              Panula, Master. Eino Viljami
# 171          172         0       3                      Rice, Master. Arthur
# 172          173         1       3              Johnson, Miss. Eleanor Ileen
# 183          184         1       2                 Becker, Master. Richard F
# ...

# %%
df[['PassengerId','Age','Fare','Ticket']][df['Age']<5.0]
# Out:
#      PassengerId   Age      Fare           Ticket
# 7              8  2.00   21.0750           349909
# 10            11  4.00   16.7000          PP 9549
# 16            17  2.00   29.1250           382652
# 43            44  3.00   41.5792    SC/Paris 2123
# 63            64  4.00   27.9000           347088
# 78            79  0.83   29.0000           248738
# 119          120  2.00   31.2750           347082
# 164          165  1.00   39.6875          3101295
# 171          172  4.00   29.1250           382652
# 172          173  1.00   11.1333           347742
# 183          184  1.00   39.0000           230136
# 184          185  4.00   22.0250           315153
# 193          194  3.00   26.0000           230080
# 205          206  2.00   10.4625           347054
# 261          262  3.00   31.3875           347077
# 297          298  2.00  151.5500           113781
# 305          306  0.92  151.5500           113781
# 340          341  2.00   26.0000           230080
# ...

# %%
avg_fare = df['Fare'].mean()
print(avg_fare)
df[df['Fare']<avg_fare]
# Out:
# 32.204207968574636
#      PassengerId  Survived  Pclass                                      Name  \
# 0              1         0       3                   Braund, Mr. Owen Harris
# 2              3         1       3                    Heikkinen, Miss. Laina
# 4              5         0       3                  Allen, Mr. William Henry
# 5              6         0       3                          Moran, Mr. James
# 7              8         0       3            Palsson, Master. Gosta Leonard
# ..           ...       ...     ...                                       ...
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
# ...

# %%
df[['Age','PassengerId']][df['Fare']<df['Fare'].mean()]
# Out:
#       Age  PassengerId
# 0    22.0            1
# 2    26.0            3
# 4    35.0            5
# 5     NaN            6
# 7     2.0            8
# ..    ...          ...
# 886  27.0          887
# 887  19.0          888
# 888   NaN          889
# 889  26.0          890
# 890  32.0          891
#
# [680 rows x 2 columns]

# %%
df[['PassengerId','Age']][df['Fare']==0]
# Out:
#      PassengerId   Age
# 179          180  36.0
# 263          264  40.0
# 271          272  25.0
# 277          278   NaN
# 302          303  19.0
# 413          414   NaN
# 466          467   NaN
# 481          482   NaN
# 597          598  49.0
# 633          634   NaN
# 674          675   NaN
# 732          733   NaN
# 806          807  39.0
# 815          816   NaN
# 822          823  38.0

# %%
# how many passenggers are male and female
len(df[['Name']][df['Sex']=='male'])
# Out:
# 577

# %%
len(df[['Name']][df['Sex']=='female'])
# Out:
# 314

# %%
# using value_couunts
df['Sex'].value_counts()
# Out:
# Sex
# male      577
# female    314
# Name: count, dtype: int64

# %%
# if i want number of percentage of male and female

df['Sex'].value_counts(normalize=True)
# Out:
# Sex
# male      0.647587
# female    0.352413
# Name: proportion, dtype: float64

# %%
# how many passenger of class 1
df[df['Pclass'] == 1]
len(df[df['Pclass'] == 1])
# Out:
# 216

# %%
# how many passengers have servied
df['Survived'].value_counts(normalize=True)
# Out:
# Survived
# 0    0.616162
# 1    0.383838
# Name: proportion, dtype: float64

# %%
# how many females have paid more than average fare
print(avg_fare)
df[['PassengerId','Name','Sex','Fare']][(df['Sex']=='female') & (df['Fare']>avg_fare)]
# Out:
# 32.204207968574636
#      PassengerId                                               Name     Sex  \
# 1              2  Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 3              4       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 31            32     Spencer, Mrs. William Augustus (Marie Eugenie)  female
# 43            44           Laroche, Miss. Simonne Marie Anne Andree  female
# 52            53           Harper, Mrs. Henry Sleeper (Myna Haxtun)  female
# ..           ...                                                ...     ...
# 853          854                          Lines, Miss. Mary Conover  female
# 856          857         Wick, Mrs. George Dennick (Mary Hitchcock)  female
# 863          864                  Sage, Miss. Dorothy Edith "Dolly"  female
# 871          872   Beckwith, Mrs. Richard Leonard (Sallie Monypeny)  female
# 879          880      Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)  female
#
#          Fare
# 1     71.2833
# ...

# %%
# how many passenger are male or  paid more than average fare
df[['Age','Name','Sex']][(df['Sex']=='male') | (df['Fare']>avg_fare)]
# Out:
#       Age                                               Name     Sex
# 0    22.0                            Braund, Mr. Owen Harris    male
# 1    38.0  Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 3    35.0       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4    35.0                           Allen, Mr. William Henry    male
# 5     NaN                                   Moran, Mr. James    male
# ..    ...                                                ...     ...
# 883  28.0                      Banfield, Mr. Frederick James    male
# 884  25.0                             Sutehall, Mr. Henry Jr    male
# 886  27.0                              Montvila, Rev. Juozas    male
# 889  26.0                              Behr, Mr. Karl Howell    male
# 890  32.0                                Dooley, Mr. Patrick    male
#
# [681 rows x 3 columns]

# %%
df[['Name','Age','Sex','Fare']][df['Fare']==max(df['Fare'])]
# Out:
#                                    Name   Age     Sex      Fare
# 258                    Ward, Miss. Anna  35.0  female  512.3292
# 679  Cardeza, Mr. Thomas Drake Martinez  36.0    male  512.3292
# 737              Lesurer, Mr. Gustave J  35.0    male  512.3292

# %%
max(df['Fare'])
# Out:
# 512.3292

# %%
# find the \
df[['Name','PassengerId','Age','Survived','Parch']][(df['Survived']==1) & (df['Parch']>3)]
# Out:
#                                                  Name  PassengerId   Age  \
# 25  Asplund, Mrs. Carl Oscar (Selma Augusta Emilia...           26  38.0
#
#     Survived  Parch
# 25         1      5

# %%
df[['Name','PassengerId','Age','Survived','Fare','family count']][(df['Survived']==1) & (df['Fare']==max(df['Fare']))]
# Out:
#                                    Name  PassengerId   Age  Survived  \
# 258                    Ward, Miss. Anna          259  35.0         1
# 679  Cardeza, Mr. Thomas Drake Martinez          680  36.0         1
# 737              Lesurer, Mr. Gustave J          738  35.0         1
#
#          Fare  family count
# 258  512.3292             0
# 679  512.3292             1
# 737  512.3292             0

# %%
df[['Name','PassengerId','Pclass','Fare','Age','Survived']][(df['Survived']==0) & (df['Pclass']==1)]
# Out:
#                                      Name  PassengerId  Pclass      Fare  \
# 6                 McCarthy, Mr. Timothy J            7       1   51.8625
# 27         Fortune, Mr. Charles Alexander           28       1  263.0000
# 30               Uruchurtu, Don. Manuel E           31       1   27.7208
# 34                Meyer, Mr. Edgar Joseph           35       1   82.1708
# 35         Holverson, Mr. Alexander Oskar           36       1   52.0000
# ..                                    ...          ...     ...       ...
# 806                Andrews, Mr. Thomas Jr          807       1    0.0000
# 815                      Fry, Mr. Richard          816       1    0.0000
# 822       Reuchlin, Jonkheer. John George          823       1    0.0000
# 867  Roebling, Mr. Washington Augustus II          868       1   50.4958
# 872              Carlsson, Mr. Frans Olof          873       1    5.0000
#
#       Age  Survived
# 6    54.0         0
# 27   19.0         0
# 30   40.0         0
# ...

# %%
df[['Name','PassengerId','Parch','Age']][(df['Parch']) & (df['Age']<5)]
# Out:
#                                        Name  PassengerId  Parch   Age
# 7            Palsson, Master. Gosta Leonard            8      1  2.00
# 10          Sandstrom, Miss. Marguerite Rut           11      1  4.00
# 16                     Rice, Master. Eugene           17      1  2.00
# 164            Panula, Master. Eino Viljami          165      1  1.00
# 171                    Rice, Master. Arthur          172      1  4.00
# 172            Johnson, Miss. Eleanor Ileen          173      1  1.00
# 183               Becker, Master. Richard F          184      1  1.00
# 193              Navratil, Master. Michel M          194      1  3.00
# 205              Strom, Miss. Telma Matilda          206      1  2.00
# 340          Navratil, Master. Edmond Roger          341      1  2.00
# 348  Coutts, Master. William Loch "William"          349      1  3.00
# 374              Palsson, Miss. Stina Viola          375      1  3.00
# ...

# %% [markdown]
# # accessing rows iloc & loc

# %% [markdown]
# Implexive Indexing: Refers to the default integer-based indexing provided by Pandas.
# Explosive Indexing: Refers to custom indexing defined by the user.
#
# 2) Implexive Indexing:
#
# This type of indexing uses integer positions to access data. For example, df.iloc is used for positional indexing.
#
# The syntax is df.iloc[start_row:end_row, start_column:end_column].
# Note that end_row and end_column are exclusive (i.e., they do not include the specified index).
#
# 3)Explosive Indexing:
#
# This type of indexing allows for manual specification of index labels. For example, df.loc is used for label-based indexing.
#
#
#
# The syntax is df.loc[start_row:end_row, start_column:end_column].
# Note that end_row and end_column are inclusive (i.e., they  include the specified index).

# %%
df.iloc[1:10,0:6]
# Out:
#    PassengerId  Survived  Pclass  \
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 2                             Heikkinen, Miss. Laina  female  26.0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 4                           Allen, Mr. William Henry    male  35.0
# 5                                   Moran, Mr. James    male   NaN
# 6                            McCarthy, Mr. Timothy J    male  54.0
# 7                     Palsson, Master. Gosta Leonard    male   2.0
# 8  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0
# ...

# %%
df2 = pd.DataFrame(np.random.randn(4,5),index=['r1','r2','r3','r4'],columns=['c1','c2','c3','c4','c5'])

# %%
df2
# Out:
#           c1        c2        c3        c4        c5
# r1 -2.148830  0.347268  1.464465  0.707746  0.782533
# r2 -0.089052  0.123785  0.415592  0.541349 -1.386463
# r3  0.511526  0.352842 -1.341441  0.362800 -0.015969
# r4  1.359614  1.778063 -0.257510 -0.413885  0.438813

# %%
df2.loc['r1':'r2','c1':'c2']
# Out:
#           c1        c2
# r1 -2.148830  0.347268
# r2 -0.089052  0.123785

# %%
df2.loc['r1':'r3','c1':'c4']
# Out:
#           c1        c2        c3        c4
# r1 -2.148830  0.347268  1.464465  0.707746
# r2 -0.089052  0.123785  0.415592  0.541349
# r3  0.511526  0.352842 -1.341441  0.362800

# %%
df2.iloc[0:3,0:4]
# Out:
#           c1        c2        c3        c4
# r1 -2.148830  0.347268  1.464465  0.707746
# r2 -0.089052  0.123785  0.415592  0.541349
# r3  0.511526  0.352842 -1.341441  0.362800

# %% [markdown]
# # concatination
# 1) horizonataly
# 2) vertically

# %%
df2.reset_index(inplace=True)

# %%
df2.drop(['index'],axis=1,inplace=True)

# %%
df2.rename(columns={'c1':'c0'})
# Out:
#          c0        c2        c3        c4        c5
# 0 -2.148830  0.347268  1.464465  0.707746  0.782533
# 1 -0.089052  0.123785  0.415592  0.541349 -1.386463
# 2  0.511526  0.352842 -1.341441  0.362800 -0.015969
# 3  1.359614  1.778063 -0.257510 -0.413885  0.438813

# %%
df3 = pd.DataFrame(np.empty((3,4)),columns=['c0','c1','c2','c4'])

# %%
df3
# Out:
#               c0             c1             c2             c4
# 0  4.940656e-324  4.940656e-324  4.940656e-324  9.881313e-324
# 1  9.881313e-324   0.000000e+00  4.940656e-324  4.940656e-324
# 2  9.881313e-324   0.000000e+00  9.881313e-324  9.881313e-324

# %%
pd.concat([df2,df3],keys=['x','y'])
# Out:
#                 c1             c2        c3             c4        c5  \
# x 0  -2.148830e+00   3.472677e-01  1.464465   7.077459e-01  0.782533
#   1  -8.905222e-02   1.237850e-01  0.415592   5.413487e-01 -1.386463
#   2   5.115256e-01   3.528421e-01 -1.341441   3.627996e-01 -0.015969
#   3   1.359614e+00   1.778063e+00 -0.257510  -4.138855e-01  0.438813
# y 0  4.940656e-324  4.940656e-324       NaN  9.881313e-324       NaN
#   1   0.000000e+00  4.940656e-324       NaN  4.940656e-324       NaN
#   2   0.000000e+00  9.881313e-324       NaN  9.881313e-324       NaN
#
#                 c0
# x 0            NaN
#   1            NaN
#   2            NaN
#   3            NaN
# y 0  4.940656e-324
#   1  9.881313e-324
#   2  9.881313e-324

# %%
df1 = df.groupby('Pclass').sum(numeric_only=True)

# %%
df1
# Out:
#         PassengerId  Survived      Age  SibSp  Parch        Fare  family count
# Pclass
# 1             99705       136  7111.42     90     77  18177.4125           167
# 2             82056        87  5168.83     74     70   3801.8417           144
# 3            215625       119  8924.92    302    193   6714.6951           495

# %%
df_1 = df[['Name','Sex','Age']][0:5]

# %%
df_1
# Out:
#                                                 Name     Sex   Age
# 0                            Braund, Mr. Owen Harris    male  22.0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 2                             Heikkinen, Miss. Laina  female  26.0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 4                           Allen, Mr. William Henry    male  35.0

# %%
df_2 = df[['Name','Sex','Age']][5:10]

# %%
df_2
# Out:
#                                                 Name     Sex   Age
# 5                                   Moran, Mr. James    male   NaN
# 6                            McCarthy, Mr. Timothy J    male  54.0
# 7                     Palsson, Master. Gosta Leonard    male   2.0
# 8  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0
# 9                Nasser, Mrs. Nicholas (Adele Achem)  female  14.0

# %%
pd.concat([df_1,df_2],keys=['x','y']) # by axis=0
# Out:
#                                                   Name     Sex   Age
# x 0                            Braund, Mr. Owen Harris    male  22.0
#   1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
#   2                             Heikkinen, Miss. Laina  female  26.0
#   3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
#   4                           Allen, Mr. William Henry    male  35.0
# y 5                                   Moran, Mr. James    male   NaN
#   6                            McCarthy, Mr. Timothy J    male  54.0
#   7                     Palsson, Master. Gosta Leonard    male   2.0
#   8  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0
#   9                Nasser, Mrs. Nicholas (Adele Achem)  female  14.0

# %%
pd.concat([df_1,df_2],axis=1,keys=['x','y'])
# Out:
#                                                    x                \
#                                                 Name     Sex   Age
# 0                            Braund, Mr. Owen Harris    male  22.0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 2                             Heikkinen, Miss. Laina  female  26.0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 4                           Allen, Mr. William Henry    male  35.0
# 5                                                NaN     NaN   NaN
# 6                                                NaN     NaN   NaN
# 7                                                NaN     NaN   NaN
# 8                                                NaN     NaN   NaN
# 9                                                NaN     NaN   NaN
#
#                                                    y
#                                                 Name     Sex   Age
# ...

# %%
df_3 = df_2.rename(index={5:0,6:1,7:2,8:3,9:4})

# %%
df_2
# Out:
#                                                 Name     Sex   Age
# 5                                   Moran, Mr. James    male   NaN
# 6                            McCarthy, Mr. Timothy J    male  54.0
# 7                     Palsson, Master. Gosta Leonard    male   2.0
# 8  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0
# 9                Nasser, Mrs. Nicholas (Adele Achem)  female  14.0

# %%
df_3
# Out:
#                                                 Name     Sex   Age
# 0                                   Moran, Mr. James    male   NaN
# 1                            McCarthy, Mr. Timothy J    male  54.0
# 2                     Palsson, Master. Gosta Leonard    male   2.0
# 3  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0
# 4                Nasser, Mrs. Nicholas (Adele Achem)  female  14.0

# %%
pd.concat([df_1,df_2],axis=0)
# Out:
#                                                 Name     Sex   Age
# 0                            Braund, Mr. Owen Harris    male  22.0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 2                             Heikkinen, Miss. Laina  female  26.0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 4                           Allen, Mr. William Henry    male  35.0
# 5                                   Moran, Mr. James    male   NaN
# 6                            McCarthy, Mr. Timothy J    male  54.0
# 7                     Palsson, Master. Gosta Leonard    male   2.0
# 8  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0
# 9                Nasser, Mrs. Nicholas (Adele Achem)  female  14.0

# %%
pd.concat([df_1,df_3])
# Out:
#                                                 Name     Sex   Age
# 0                            Braund, Mr. Owen Harris    male  22.0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 2                             Heikkinen, Miss. Laina  female  26.0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 4                           Allen, Mr. William Henry    male  35.0
# 0                                   Moran, Mr. James    male   NaN
# 1                            McCarthy, Mr. Timothy J    male  54.0
# 2                     Palsson, Master. Gosta Leonard    male   2.0
# 3  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0
# 4                Nasser, Mrs. Nicholas (Adele Achem)  female  14.0

# %%
data = {
    'a':[1,2,3,4],
    'b':[5,6,7,8]
}

data2 = {
    'c':[11,12],
    'd':[13,14]
}

# %%
df3 = pd.DataFrame(data)

# %%
df4 = pd.DataFrame(data2,index=[0,1])

# %%
df3
# Out:
#    a  b
# 0  1  5
# 1  2  6
# 2  3  7
# 3  4  8

# %%
df4
# Out:
#     c   d
# 0  11  13
# 1  12  14

# %%
result1 = pd.concat([df3,df4],keys=['row1','row2'])

# %%
result1
# Out:
#           a    b     c     d
# row1 0  1.0  5.0   NaN   NaN
#      1  2.0  6.0   NaN   NaN
#      2  3.0  7.0   NaN   NaN
#      3  4.0  8.0   NaN   NaN
# row2 0  NaN  NaN  11.0  13.0
#      1  NaN  NaN  12.0  14.0

# %%
result2 = pd.concat([df3,df4],keys=['row1','row2'],axis=1)

# %%
result2
# Out:
#   row1     row2
#      a  b     c     d
# 0    1  5  11.0  13.0
# 1    2  6  12.0  14.0
# 2    3  7   NaN   NaN
# 3    4  8   NaN   NaN

# %%
# Group by 'Survived' and aggregate only numeric columns
numeric_cols = df.select_dtypes(include=['number']).columns
df.groupby('Survived')[numeric_cols].agg(['max', 'min'])
# Out:
#          PassengerId     Survived     Pclass       Age       SibSp     Parch  \
#                  max min      max min    max min   max   min   max min   max
# Survived
# 0                891   1        0   0      3   1  74.0  1.00     8   0     6
# 1                890   2        1   1      3   1  80.0  0.42     4   0     5
#
#                   Fare      family count
#          min       max  min          max min
# Survived
# 0          0  263.0000  0.0           10   0
# 1          0  512.3292  0.0            6   0

# %%
df_1
# Out:
#                                                 Name     Sex   Age
# 0                            Braund, Mr. Owen Harris    male  22.0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 2                             Heikkinen, Miss. Laina  female  26.0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 4                           Allen, Mr. William Henry    male  35.0

# %%
df_2
# Out:
#                                                 Name     Sex   Age
# 5                                   Moran, Mr. James    male   NaN
# 6                            McCarthy, Mr. Timothy J    male  54.0
# 7                     Palsson, Master. Gosta Leonard    male   2.0
# 8  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0
# 9                Nasser, Mrs. Nicholas (Adele Achem)  female  14.0

# %%
df_3
# Out:
#                                                 Name     Sex   Age
# 0                                   Moran, Mr. James    male   NaN
# 1                            McCarthy, Mr. Timothy J    male  54.0
# 2                     Palsson, Master. Gosta Leonard    male   2.0
# 3  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0
# 4                Nasser, Mrs. Nicholas (Adele Achem)  female  14.0

# %%
pd.concat([df_1,df_2],axis=0)  # by default it concat row wise
# Out:
#                                                 Name     Sex   Age
# 0                            Braund, Mr. Owen Harris    male  22.0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 2                             Heikkinen, Miss. Laina  female  26.0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 4                           Allen, Mr. William Henry    male  35.0
# 5                                   Moran, Mr. James    male   NaN
# 6                            McCarthy, Mr. Timothy J    male  54.0
# 7                     Palsson, Master. Gosta Leonard    male   2.0
# 8  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0
# 9                Nasser, Mrs. Nicholas (Adele Achem)  female  14.0

# %%
pd.concat([df_1,df_2],axis=1) #in axis =1 
# where it concate df_1 and df_2 columns siws but whenever index are not same then it will
# Out:
#                                                 Name     Sex   Age  \
# 0                            Braund, Mr. Owen Harris    male  22.0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 2                             Heikkinen, Miss. Laina  female  26.0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 4                           Allen, Mr. William Henry    male  35.0
# 5                                                NaN     NaN   NaN
# 6                                                NaN     NaN   NaN
# 7                                                NaN     NaN   NaN
# 8                                                NaN     NaN   NaN
# 9                                                NaN     NaN   NaN
#
#                                                 Name     Sex   Age
# 0                                                NaN     NaN   NaN
# 1                                                NaN     NaN   NaN
# ...

# %% [markdown]
# # Merge

# %% [markdown]
# NOTE 🗼: Baiscally merge and join are same as merege
#
# df.merge(): join dataframe or named sries object with database style join.it
#
# it works on column (which are common)

# %%
df1 = pd.DataFrame({'key1':[1,2,4,5,6],
                      'key2':[4,5,6,7,8],
                      'key3':[3,4,5,6,6]
})

# %%
df2 =  pd.DataFrame({'key1':[1,2,45,6,67],
                      'key4':[56,5,6,7,8],
                      'key5':[3,56,5,6,6]
}
)

# %%
df1
# Out:
#    key1  key2  key3
# 0     1     4     3
# 1     2     5     4
# 2     4     6     5
# 3     5     7     6
# 4     6     8     6

# %%
df2
# Out:
#    key1  key4  key5
# 0     1    56     3
# 1     2     5    56
# 2    45     6     5
# 3     6     7     6
# 4    67     8     6

# %%
pd.merge(df1,df2,how='left')
# all the element from left side and common element of right side
# Out:
#    key1  key2  key3  key4  key5
# 0     1     4     3  56.0   3.0
# 1     2     5     4   5.0  56.0
# 2     4     6     5   NaN   NaN
# 3     5     7     6   NaN   NaN
# 4     6     8     6   7.0   6.0

# %% [markdown]
# explinination :
#
# pd.merge(df1,df2,how='left')
#
# where,
#
# df1 = is left table
#
# df2 = is right table
#
# (how=left) = innidactes we are going to perform left join (database)
#
# first it prints all element from left table(df1) and coomon element of right table(df2

# %%
df1
# Out:
#    key1  key2  key3
# 0     1     4     3
# 1     2     5     4
# 2     4     6     5
# 3     5     7     6
# 4     6     8     6

# %%
df2
# Out:
#    key1  key4  key5
# 0     1    56     3
# 1     2     5    56
# 2    45     6     5
# 3     6     7     6
# 4    67     8     6

# %%
# right join 
pd.merge(df1,df2,how='right')
# Out:
#    key1  key2  key3  key4  key5
# 0     1   4.0   3.0    56     3
# 1     2   5.0   4.0     5    56
# 2    45   NaN   NaN     6     5
# 3     6   8.0   6.0     7     6
# 4    67   NaN   NaN     8     6

# %%
# inner join : return only return common elemnet based on key
pd.merge(df1,df2,how='inner')
# Out:
#    key1  key2  key3  key4  key5
# 0     1     4     3    56     3
# 1     2     5     4     5    56
# 2     6     8     6     7     6

# %%
# cross join: cartestion of left tables common colum row with right table common column
pd.merge(df1,df2,how='cross')
# Out:
#     key1_x  key2  key3  key1_y  key4  key5
# 0        1     4     3       1    56     3
# 1        1     4     3       2     5    56
# 2        1     4     3      45     6     5
# 3        1     4     3       6     7     6
# 4        1     4     3      67     8     6
# 5        2     5     4       1    56     3
# 6        2     5     4       2     5    56
# 7        2     5     4      45     6     5
# 8        2     5     4       6     7     6
# 9        2     5     4      67     8     6
# 10       4     6     5       1    56     3
# 11       4     6     5       2     5    56
# 12       4     6     5      45     6     5
# 13       4     6     5       6     7     6
# 14       4     6     5      67     8     6
# 15       5     7     6       1    56     3
# 16       5     7     6       2     5    56
# 17       5     7     6      45     6     5
# 18       5     7     6       6     7     6
# 19       5     7     6      67     8     6
# 20       6     8     6       1    56     3
# ...

# %%
df1
# Out:
#    key1  key2  key3
# 0     1     4     3
# 1     2     5     4
# 2     4     6     5
# 3     5     7     6
# 4     6     8     6

# %%
df2
# Out:
#    key1  key4  key5
# 0     1    56     3
# 1     2     5    56
# 2    45     6     5
# 3     6     7     6
# 4    67     8     6

# %%
#  outer join 
pd.merge(df1,df2,how='outer')
# Out:
#    key1  key2  key3  key4  key5
# 0     1   4.0   3.0  56.0   3.0
# 1     2   5.0   4.0   5.0  56.0
# 2     4   6.0   5.0   NaN   NaN
# 3     5   7.0   6.0   NaN   NaN
# 4     6   8.0   6.0   7.0   6.0
# 5    45   NaN   NaN   6.0   5.0
# 6    67   NaN   NaN   8.0   6.0

# %% [markdown]
# 1) here df1 key 1 first rows with all columns of df2

# %%
df1
# Out:
#    key1  key2  key3
# 0     1     4     3
# 1     2     5     4
# 2     4     6     5
# 3     5     7     6
# 4     6     8     6

# %%
df2
# Out:
#    key1  key4  key5
# 0     1    56     3
# 1     2     5    56
# 2    45     6     5
# 3     6     7     6
# 4    67     8     6

# %%
# now all merge(sql joints) are perform on common column from both data frame but now we want to perform 
# merge based on own column (key) so we are going to use 2 parametr let see..
# left_on , right_on 
pd.merge(df1,df2,left_on='key2',right_on='key4',how='left') # here the common column name will change
# Out:
#    key1_x  key2  key3  key1_y  key4  key5
# 0       1     4     3     NaN   NaN   NaN
# 1       2     5     4     2.0   5.0  56.0
# 2       4     6     5    45.0   6.0   5.0
# 3       5     7     6     6.0   7.0   6.0
# 4       6     8     6    67.0   8.0   6.0

# %% [markdown]
# | Feature                  | **`pd.merge()`**                                      | **`DataFrame.join()`**                                   |
# |--------------------------|-------------------------------------------------------|----------------------------------------------------------|
# | **Primary Use**           | Combines DataFrames using columns as keys.            | Combines DataFrames using their indexes (default).        |
# | **Key or Index**          | Works with **column keys**. Can also use indexes with `left_index=True`, `right_index=True`. | Primarily works with **indexes**. Can use columns via `on`. |
# | **Flexibility**           | More flexible: merges on columns or indexes, handles different column names. | Simpler: index-based joins mainly, limited column-based joins. |
# | **Method**                | Standalone function: `pd.merge(df1, df2, ...)`.       | DataFrame method: `df1.join(df2, ...)`.                   |
# | **Default Join Type**     | `inner` join (only matching rows).                    | `left` join (all rows from left DataFrame).               |
# | **Column Duplication**    | Adds suffixes (`_x`, `_y`) for matching columns.      | Can lead to duplicate columns if same column names exist. |
# | **Performance**           | More computationally intensive for complex merges.    | Faster for simpler index-based joins.                     |
# | **Use Cases**             | Best for column-based joins, handling complex operations. | Best for simple index-based joins.                        |
# | **SQL-style Joins**       | Supports `inner`, `outer`, `left`, `right` joins.     | Primarily `left` join, but supports other types (`inner`, `outer`, `right`). |

# %%
df1.rename({0:'a',1:'b','b':'d',3:'g',4:'h'},inplace=True)
df2.rename({0:'d',1:'g',2:'a',3:'d',4:'h'},inplace=True)

# %%
df1
# Out:
#    key1  key2  key3
# a     1     4     3
# d     2     5     4
# c     4     6     5
# g     5     7     6
# h     6     8     6

# %%
df2
# Out:
#    key1  key4  key5
# d     1    56     3
# g     2     5    56
# a    45     6     5
# d     6     7     6
# h    67     8     6

# %%
df1.join(df2,how='right',lsuffix='_x',rsuffix='_y') # here we have use lsuffix rsuffix avoid errror 
# ValueError: columns overlap but no suffix specified
# Out:
#    key1_x  key2  key3  key1_y  key4  key5
# d       2     5     4       1    56     3
# g       5     7     6       2     5    56
# a       1     4     3      45     6     5
# d       2     5     4       6     7     6
# h       6     8     6      67     8     6

# %%
df1.join(df2,how='inner',lsuffix='_x',rsuffix='_y')
# Out:
#    key1_x  key2  key3  key1_y  key4  key5
# a       1     4     3      45     6     5
# d       2     5     4       1    56     3
# d       2     5     4       6     7     6
# g       5     7     6       2     5    56
# h       6     8     6      67     8     6

# %% [markdown]
# # apply ()
#
# it method apply function to dataframe index wise

# %%
df['gendar']=df['Sex'].apply(lambda x: 1 if x=='male' else 0)

# %%
df['gendar'].value_counts()
# Out:
# gendar
# 1    577
# 0    314
# Name: count, dtype: int64

# %%
df['Fare'].mean()
# Out:
# 32.204207968574636

# %%
df['class']=df.apply(lambda row,avg_fare=32: 'high' if row['Fare']>avg_fare else 'cheap'if row['Fare']<avg_fare else 'descent',axis=1 )

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...
